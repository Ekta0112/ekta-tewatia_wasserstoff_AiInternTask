# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pytesseract
# !pip install streamlit -q
# !pip install yolov5 # install the missing module
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# !pip install pytesseract
# !pip install Pillow
# !apt-get install tesseract-ocr
# !which tesseract
# Out:
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (10.4.0)
# Collecting yolov5
#   Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl.metadata (10 kB)
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.10/dist-packages (from yolov5) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from yolov5) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from yolov5) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from yolov5) (10.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from yolov5) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (1.13.1)
# Collecting thop>=0.1.1 (from yolov5)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.4.1+cu121)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (0.19.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (4.66.5)
# Requirement already satisfied: ultralytics>=8.0.100 in /usr/local/lib/python3.10/dist-packages (from yolov5) (8.2.103)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.17.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (0.13.1)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (71.0.4)
# Collecting fire (from yolov5)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 915.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting boto3>=1.19.1 (from yolov5)
#   Downloading boto3-1.35.29-py3-none-any.whl.metadata (6.6 kB)
# Collecting sahi>=0.11.10 (from yolov5)
#   Downloading sahi-0.11.18-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (0.24.7)
# Collecting roboflow>=0.2.29 (from yolov5)
#   Downloading roboflow-1.1.45-py3-none-any.whl.metadata (9.7 kB)
# Collecting botocore<1.36.0,>=1.35.29 (from boto3>=1.19.1->yolov5)
#   Downloading botocore-1.35.29-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.19.1->yolov5)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.19.1->yolov5)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython>=3.1.30->yolov5) (4.0.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (24.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->yolov5) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->yolov5) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (2024.8.30)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->yolov5)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow>=0.2.29->yolov5) (4.10.0.84)
# Collecting python-dotenv (from roboflow>=0.2.29->yolov5)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow>=0.2.29->yolov5) (1.16.0)
# Collecting requests-toolbelt (from roboflow>=0.2.29->yolov5)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow>=0.2.29->yolov5)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting opencv-python>=4.1.1 (from yolov5)
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.11.10->yolov5) (2.0.6)
# Collecting pybboxes==0.1.6 (from sahi>=0.11.10->yolov5)
#   Downloading pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting terminaltables (from sahi>=0.11.10->yolov5)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sahi>=0.11.10->yolov5) (8.1.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (3.0.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (3.1.4)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.0.100->yolov5) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.0.100->yolov5) (2.0.8)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->yolov5) (2.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->yolov5) (1.3.0)
# Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.4/953.4 kB 6.9 MB/s eta 0:00:00
# Downloading boto3-1.35.29-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 10.0 MB/s eta 0:00:00
# Downloading roboflow-1.1.45-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 5.6 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.9 MB/s eta 0:00:00
# Downloading sahi-0.11.18-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 8.9 MB/s eta 0:00:00
# Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 14.5 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading botocore-1.35.29-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 57.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 6.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.2 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=47953d258e33503a7bf62605e87f5c66d553fae8abe6bf7fd71c885c215a2f46
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: filetype, terminaltables, python-dotenv, pybboxes, opencv-python, jmespath, idna, fire, botocore, thop, sahi, s3transfer, requests-toolbelt, roboflow, boto3, yolov5
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed boto3-1.35.29 botocore-1.35.29 filetype-1.2.0 fire-0.6.0 idna-3.7 jmespath-1.0.1 opencv-python-4.9.0.80 pybboxes-0.1.6 python-dotenv-1.0.1 requests-toolbelt-1.0.0 roboflow-1.1.45 s3transfer-0.10.2 sahi-0.11.18 terminaltables-3.1.10 thop-0.1.1.post2209072238 yolov5-7.0.13
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (3,537 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 123614 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (10.4.0)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (10.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (10.4.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/bin/tesseract

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.134.72.209

# %%
# !npm install -g localtunnel@2.0.2
# Out:
# added 22 packages, and audited 23 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 1 moderate severity vulnerability
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.

# %%
# !streamlit run /content/drive/MyDrive/Image_Segmentation/Project_root/streamlit_app/app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.134.72.209:8501
#
# your url is: https://fresh-clouds-prove.loca.lt
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaskRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=MaskRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# 2024-09-29 18:45:55.761446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-29 18:45:55.791507: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-29 18:45:55.800209: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-29 18:46:05.548 Session with id 2c240ad8-3cca-4d27-bd49-ed325b22fa72 is already connected! Connecting to a new session.
# Extracted 35 objects and saved them to /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects.
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_15.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_16.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_17.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_18.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_19.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_20.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_21.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_22.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_23.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_24.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_25.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_26.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_2.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_7.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_4.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_9.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_8.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_5.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_1.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_3.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_6.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_10.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_14.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_12.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_13.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_11.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_27.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_28.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_29.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_30.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_31.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_32.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_33.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_34.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_35.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Object descriptions saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/object_metadata.csv
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_15.png...
# Text from object_15.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_16.png...
# Text from object_16.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_17.png...
# Text from object_17.png: |
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_18.png...
# Text from object_18.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_19.png...
# Text from object_19.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_20.png...
# Text from object_20.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_21.png...
# Text from object_21.png: re
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_22.png...
# Text from object_22.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_23.png...
# Text from object_23.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_24.png...
# Text from object_24.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_25.png...
# Text from object_25.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_26.png...
# Text from object_26.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_2.png...
# Text from object_2.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_7.png...
# Text from object_7.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_4.png...
# Text from object_4.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_9.png...
# Text from object_9.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_8.png...
# Text from object_8.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_5.png...
# Text from object_5.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_1.png...
# Text from object_1.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_3.png...
# Text from object_3.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_6.png...
# Text from object_6.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_10.png...
# Text from object_10.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_14.png...
# Text from object_14.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_12.png...
# Text from object_12.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_13.png...
# Text from object_13.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_11.png...
# Text from object_11.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_27.png...
# Text from object_27.png: 4.
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_28.png...
# Text from object_28.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_29.png...
# Text from object_29.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_30.png...
# Text from object_30.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_31.png...
# Text from object_31.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_32.png...
# Text from object_32.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_33.png...
# Text from object_33.png: Ea
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_34.png...
# Text from object_34.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_35.png...
# Text from object_35.png:
# Extracted text saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/text_data_tesseract.csv
# config.json: 100% 1.58k/1.58k [00:00<00:00, 2.11MB/s]
# model.safetensors: 100% 1.63G/1.63G [00:16<00:00, 97.7MB/s]
# generation_config.json: 100% 363/363 [00:00<00:00, 2.11MB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 14.1MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 24.5MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 15.3MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Summarizing attributes for object_3...
# Your max_length is set to 50, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Summarizing attributes for object_7...
# Your max_length is set to 50, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Summarizing attributes for object_27...
# Your max_length is set to 50, but your input_length is only 4. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Summarizing attributes for object_33...
# Your max_length is set to 50, but your input_length is only 4. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Summarized attributes saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/summarized_attributes.csv
# Data mapping saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/data_mapping.json
# Annotated image saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/annotated_image.png
# Summary table saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/summary_table.csv
# Extracted 14 objects and saved them to /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects.
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_2.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_7.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_4.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_9.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_8.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_5.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_1.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_3.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_6.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_10.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_14.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_12.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_13.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_11.png...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Object descriptions saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/object_metadata.csv
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_2.png...
# Text from object_2.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_7.png...
# Text from object_7.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_4.png...
# Text from object_4.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_9.png...
# Text from object_9.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_8.png...
# Text from object_8.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_5.png...
# Text from object_5.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_1.png...
# Text from object_1.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_3.png...
# Text from object_3.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_6.png...
# Text from object_6.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_10.png...
# Text from object_10.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_14.png...
# Text from object_14.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_12.png...
# Text from object_12.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_13.png...
# Text from object_13.png:
# Extracting text from /content/drive/MyDrive/Image_Segmentation/Project_root/data/segmented_objects/object_11.png...
# Text from object_11.png:
# Extracted text saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/text_data_tesseract.csv
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Summarized attributes saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/summarized_attributes.csv
# Data mapping saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/data_mapping.json
# Annotated image saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/annotated_image.png
# Summary table saved to /content/drive/MyDrive/Image_Segmentation/Project_root/data/output/summary_table.csv
